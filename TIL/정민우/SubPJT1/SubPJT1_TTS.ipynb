# %% [markdown]
# # Text-to-Speech
# Speech synthesis (text-to-speech) 모델 중 하나인 YourTTS를 활용해 직접 텍스트 입력하고 음성 wav 신호로 변환 후 들어봅니다.
# 학습 목표는 다음과 같습니다.
#
# 1. 텍스트를 입력으로 음성 파일 합성 후 재생
# 2. 입력 텍스트 전처리에 따른 결과 변화의 이해

# %% [markdown]
# ### 필요 패키지 install & import

# %%
# !pip install TTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.1/604.1 KB 9.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 38.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 KB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 36.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 KB 3.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 42.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 KB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 KB 3.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 577.3/577.3 KB 24.6 MB/s eta 0:00:00
# ...

# %%
from TTS.api import TTS
import IPython.display as ipd
import re

# %% [markdown]
# # Req.2-1 TTS
# TODO-1, 2를 수행하시오.

# %% [markdown]
# ### model definition
# pre-trained TTS 모델을 불러옵니다.

# %%
model_name = TTS.list_models()[0]
# Init TTS
tts = TTS(model_name)
# Out:
#  > tts_models/multilingual/multi-dataset/your_tts is already downloaded.
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
# ...

# %% [markdown]
# ### speech synthesis
# 주어진 텍스트를 입력으로 음성 신호를 합성합니다.

# %%
input_text = "This is for the SSAFY audio artificial intelligence track."
wav = tts.tts(input_text, speaker=tts.speakers[0], language=tts.languages[0])
# Out:
#  > Text splitted to sentences.
# ['This is for the SSAFY audio artificial intelligence track.']
#  > Processing time: 1.6674935817718506
#  > Real-time factor: 0.3496526696942442

# %% [markdown]
# **TODO-1**: 합성된 wav를 재생하기 위해선 sample rate 정보가 필요합니다.
# 다음의 힌트를 통해 sample rate를 추정하고 wav 신호를 재생하시오.

# %%
"""
Hint: 아래 코드는 tts.tts 함수의 마지막 실행 코드입니다. 
# process_time = time.time() - start_time
# audio_time = len(wavs) / self.tts_config.audio["sample_rate"]
# print(f" > Processing time: {process_time}")
# print(f" > Real-time factor: {process_time / audio_time}")
"""
# Out:
# '\nHint: 아래 코드는 tts.tts 함수의 마지막 실행 코드입니다. \n# process_time = time.time() - start_time\n# audio_time = len(wavs) / self.tts_config.audio["sample_rate"]\n# print(f" > Processing time: {process_time}")\n# print(f" > Real-time factor: {process_time / audio_time}")\n'

# %%
ipd.Audio(wav, rate=(len(wav) / 4.5))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# **TODO-2**: 입력 텍스트에 영어가 아닌 문자가 많을 때 결과가 어떻게 나오는지 확인하고, 전처리 후 다시 결과를 확인해보시오.

# %%
input_text = "Th%&#is is for !@%@!$the SS가나다라AFY audio arti%&#ficial intel!@%ligence track."
wav = tts.tts(input_text, speaker=tts.speakers[0], language=tts.languages[0])
# Out:
#  > Text splitted to sentences.
# ['Th%&#is is for !', '@%@!', '$the SS가나다라AFY audio arti%&#ficial intel!', '@%ligence track.']
# ['<BLNK>', 't', '<BLNK>', 'h', '<BLNK>', '%', '<BLNK>', '&', '<BLNK>', '#', '<BLNK>', 'i', '<BLNK>', 's', '<BLNK>', ' ', '<BLNK>', 'i', '<BLNK>', 's', '<BLNK>', ' ', '<BLNK>', 'f', '<BLNK>', 'o', '<BLNK>', 'r', '<BLNK>', ' ', '<BLNK>', '!', '<BLNK>']
#  [!] Character '%' not found in the vocabulary. Discarding it.
# ['<BLNK>', 't', '<BLNK>', 'h', '<BLNK>', '%', '<BLNK>', '&', '<BLNK>', '#', '<BLNK>', 'i', '<BLNK>', 's', '<BLNK>', ' ', '<BLNK>', 'i', '<BLNK>', 's', '<BLNK>', ' ', '<BLNK>', 'f', '<BLNK>', 'o', '<BLNK>', 'r', '<BLNK>', ' ', '<BLNK>', '!', '<BLNK>']
#  [!] Character '&' not found in the vocabulary. Discarding it.
# ...

# %%
## TODO-2 ##
# input text 전처리 후 다시 음성 신호를 합성하세요.

# 정규표현식을 사용하여 영어 알파벳과 공백을 제외한 모든 문자 제거
input_text = re.sub('[^a-zA-Z\s]', '', input_text)

# 합성할 음성 신호 생성
wav = tts.tts(input_text, speaker=tts.speakers[0], language=tts.languages[0])
# Out:
#  > Text splitted to sentences.
# ['This is for the SSAFY audio artificial intelligence track']
#  > Processing time: 2.3207504749298096
#  > Real-time factor: 0.48500532391427575

# %%
ipd.Audio(wav, rate=(len(wav) / 4.5))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
